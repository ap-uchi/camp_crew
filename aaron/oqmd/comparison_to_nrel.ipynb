# %%
import glob
import os
import pickle as pkl
import re
import sys

from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from tqdm import tqdm

# %%
with open('../../datasets/oqmd_dataset.pkl', "rb") as f:
    oqmd_db = pkl.load(f)

# %%
oqmd_useful = oqmd_db.dropna(axis=1)
oqmd_useful
# Out:
#           name  entry_id composition_generic spacegroup   volume  ntypes  \
# 0       DyRuO3   1730890                ABC3     I4/mcm  116.984       3
# 1       DyScO3   1730891                ABC3     I4/mcm  121.878       3
# 2        DyVO3   1730892                ABC3     I4/mcm  112.458       3
# 3       DyZrO3   1730893                ABC3     I4/mcm  130.633       3
# 4       ErLuO3   1730894                ABC3     I4/mcm  132.569       3
# ...        ...       ...                 ...        ...      ...     ...
# 23107   MgRuO3   1738575                ABC3      Cmc21  148.688       3
# 23108   MgTiO3   1738576                ABC3      Cmc21  141.714       3
# 23109  CeLuSe3   1739101                ABC3      C2221  267.084       3
# 23110   NdSeO3   1739235                ABC3      P21/m  134.123       3
# 23111   PdPbO3   1739236                ABC3      P21/m  134.204       3
#
#        natoms   delta_e  stability
# 0          10 -2.209178   0.286549
# ...

# %%
with open("oqmd_ids.pkl", "wb") as wf:
    pkl.dump(oqmd_useful["entry_id"], wf)

# %%
oqmd_useful["name"].str.
